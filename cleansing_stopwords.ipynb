# %%
import pandas as pd

# %%
data = pd.read_csv('data/job_feature.csv').columns
combined_words = [i[0] for i in pd.read_csv('data/combined_root_words.txt').values] + [i[0] for i in pd.read_csv('data/words_alpha.txt').values]
combined_words = list(set(combined_words))

# %%
len(data), len(combined_words)
# Out:
# (1160, 394549)

# %%
notin = [i for i in data if i not in combined_words]
imin = [i for i in data if i in combined_words]

# %%
'selesai' in combined_words
# Out:
# False

# %%
for i in notin:
    print(i)
# Out:
# Unnamed: 0
# 0
# 00
# 10
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 29
# 30
# 35
# 38
# 40
# 45
# aktifitasnya
# akunnya
# analisa
# anggaran
# apapun
# arahan
# assest
# atasan
# atk
# attentation
# atu
# autocad
# bangunan
# belajar
# beracara
# berbahasa
# bergabung
# berhubungan
# berinteraksi
# berjalan
# berjangka
# berjiwa
# berkaitan
# berkala
# berkomunikasi
# berkontribusi
# berkualitas
# berlaku
# bermain
# berpenampilan
# berpengalaman
# berperilaku
# berpikir
# bersedia
# bersidang
# bertanggung
# bertanggungjawab
# bertannggung
# berurusan
# beserta
# bhs
# biaya
# bidangnya
# bongkaran
# bulanan
# bulannya
# bussines
# cashflow
# catatan
# cctv
# conten
# corel
# corprate
# d3
# daycare
# dhcp
# diajukan
# dianggarkan
# diatahkan
# dibangun
# dibawah
# dibidang
# dibidangnya
# dibutuhkan
# didirikan
# didiskusikan
# diinstruksikan
# dilaporkan
# diluar
# dipertahankan
# diposisi
# direncanakan
# diselidiki
# disetujui
# disewakan
# displin
# disukai
# ditanggapi
# ...
