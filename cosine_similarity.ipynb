# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from transform import remove_html, maintain_alpha, remove_single, remove_morespace

# %%
pd.set_option('display.max_colwidth', 10)
pd.set_option('display.max_columns', None)

# %%
df_job = pd.read_csv('data/cdf_job.csv')
df_applicant = pd.read_csv('data/cdf_applicant.csv')
df_applicant_experience = pd.read_csv('data/cdf_applicant_experience.csv')

df_function_position = pd.read_csv('data/df_function_position.csv', index_col=['FunctionPositionID'])
df_job = pd.merge(df_job, df_function_position, on=['FunctionPositionID'])

df_job = df_job[['JobID', 'Description', 'JobTitle', 'Requirement', 'FunctionPositionName']]

df_applicant = df_applicant[['ApplicantID', 'Strengthness', 'Weaknesses']]
df_applicant_experience = df_applicant_experience[['ApplicantID', 'Industry', 'JobDescription', 'Position']]

df_applicant = pd.merge(df_applicant, df_applicant_experience, on=['ApplicantID'])

# %%
df_applicant.head(2)
# Out:
#    ApplicantID Strengthness Weaknesses   Industry JobDescription   Position
# 0          1            0            0  jasa k...  pembua...      staff ...
# 1          3    pekerj...    pelupa...  teleko...  mainte...      sales ...

# %%
df_job.set_index('JobID', inplace=True)
df_job = df_job.astype(str)

df_applicant.set_index('ApplicantID', inplace=True)
df_applicant = df_applicant.astype(str)

# %%
df_job = df_job.applymap(str.lower).applymap(remove_html).applymap(maintain_alpha).applymap(remove_single).applymap(remove_morespace).applymap(str.strip)
df_applicant = df_applicant.applymap(str.lower).applymap(remove_html).applymap(maintain_alpha).applymap(remove_single).applymap(remove_morespace).applymap(str.strip)
# Out:
# c:\Users\eats\projects\eris_job\transform.py:46: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 46 of the file c:\Users\eats\projects\eris_job\transform.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   return BeautifulSoup(text).get_text()
# c:\Users\eats\miniconda3\envs\p1\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
df_applicant.head(3)
# Out:
#            Strengthness Weaknesses   Industry JobDescription   Position
# Applica...
# 1                                   jasa k...  pembua...      staff ...
# 3           pekerj...    pelupa...  teleko...  mainte...      sales ...
# 10          konsis...    terlal...  event ...  bertug...      market...

# %%
df_job['JobID'] = df_job.index
df_job['Text'] = df_job.Description + df_job.JobTitle + df_job.Requirement + df_job.FunctionPositionName
df_job.drop(columns=['Description', 'JobTitle', 'Requirement', 'FunctionPositionName'], inplace=True)

df_applicant['ApplicantID'] = df_applicant.index
df_applicant['History'] = df_applicant.Strengthness + df_applicant.Weaknesses + df_applicant.Industry + df_applicant.JobDescription + df_applicant.Position
df_applicant.drop(columns=['Strengthness', 'Weaknesses', 'Industry', 'JobDescription', 'Position'])
# Out:
#             ApplicantID    History
# Applica...
# 1                   1    jasa k...
# 3                   3    pekerj...
# 10                 10    konsis...
# 13                 13    swotsw...
# 18                 18    pemeri...
# ...               ...          ...
# 44921           44921    furnit...
# 44922           44922    pt har...
# 44925           44925    keuang...
# 44928           44928    indust...
# 44929           44929    pt evo...
#
# [5427 rows x 2 columns]

# %%
df_applicant.drop(columns=['ApplicantID'], inplace=True)

# %%
df_job.drop(columns=['JobID'], inplace=True)

# %%
from sklearn.cluster import KMeans
import re

# %%
df_job.Text = df_job.Text.apply(lambda x: re.sub('yang|tahun|membuat|di|dengan|dan|kepada|secara|at|and|to|in|become|untuk|di|years|as|for|be|with|of|the|in|memiliki|mimal|jawab|sur|all|reled|let|or|au|melakukan|mengerjakan|pada|shootg|apliki|admistri|hil|gunakan|ngkel|targetnyamelakukan|samamemiliki|prospektifmengembangkan|lebih|networkg|marketg|able', '', x))

# %%
tfidf_vectorizer = TfidfVectorizer()

job_tfidf = tfidf_vectorizer.fit_transform((df_job.Text))
user_tfidf = tfidf_vectorizer.transform(df_applicant.History)

kmeans = KMeans(random_state=42)
kmeans.fit(job_tfidf)

clusters = kmeans.labels_
# Out:
# c:\Users\eats\miniconda3\envs\p1\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
cosine_sim = linear_kernel(job_tfidf, job_tfidf)

# %%
original = pd.read_csv('data/cdf_job.csv')

# %%
original.head(2)
# Out:
#    JobID Description  EducationLevelID  FunctionPositionID JobStatus  \
# 0      1  under ...           4                 1              Close
# 1      2  becomi...           2                 2              Close
#
#     JobTitle Requirement  SalaryMax  SalaryMin  HiredQuota  DepartmentID  \
# 0  night ...  with y...     3600000    3300000          1           1
# 1  book k...  bachel...     4250000    3500000          1           2
#
#    CityID  CompanyID  ProvinceID  SkipTest  MajorID     DbName  UsiaMax  \
# 0       1          7          1       True        1  WarnaW...      0.0
# 1       1          7          1       True        2  WarnaW...      0.0
#
#   UsingGlasses  IQMin  IsSpecificEducationLevel DriverLicenseType  \
# 0      False        0      False                         0
# 1      False        0      False                         0
#
#    IsSpesificDriverLicense  Gender  IsSpecificAge  IsSpecificGender  \
# 0      False                     0      False          False
# 1      False                     0      False          False
#
#    IsSpecificIQ  IsSpecificMarital  MaritalStatus  AdsStatisticID
# 0      False         False                  0              0
# 1      False         False                  0              0

# %%
indices
# Out:
# JobTitle
# night audit                     0
# book keeper                     1
# it android programmer           2
# sekretaris legal                3
# sekretaris direksi              4
#                              ...
# general manager hotel         921
# marketing staff               922
# manager finance accounting    923
# general affair ga             924
# social media officer          925
# Length: 926, dtype: int64

# %%
indices = pd.Series(original.index, index=original['JobTitle']).drop_duplicates()

# %%
def get_recommendations_cb(title, cosine_sim=cosine_sim):
    index = indices.str.contains(title)
    sim_scores = list(enumerate(cosine_sim[index]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    print(movie_indices)
    return original['JobTitle'].iloc[movie_indices]

# %%
df = pd.DataFrame(job_tfidf.todense()).groupby(clusters).mean()

# %%
terms = tfidf_vectorizer.get_feature_names_out()

# %%
for i,r in df.iterrows():
    print('cluster', i)
    print(','.join([terms[t] for t in np.argsort(r)[-100:]]))
# Out:
# cluster 0
# kegian,pelaksanaan,apartment,memrikan,manager,penagihan,hubungan,charge,legusia,fance,tempo,juh,setiap,voice,utility,calon,rtanggung,keluhan,barang,out,program,menjalankan,pertanggung,penawaranadm,big,setelah,segala,perubahan,meetg,menyusun,dokumen,kerja,peralan,la,star,sebagai,sewa,gunawangsa,perusahaan,jadwal,keselaman,chief,lapan,relion,property,faktur,dap,membantu,sesuai,pengalaman,jurusan,unit,koni,target,maksimal,dari,gedung,akuntansi,accountg,baik,staff,proses,bank,penkan,admistri,karyawan,memonir,ada,pekerjaan,skill,serta,khusus,sipl,penempan,kecil,engeerg,pajak,komunikif,iented,penyewa,isiif,keuangan,tugkan,prosedur,leg,presention,tanggung,detail,jujur,mempunyai,oleh,penghuni,lanya,departemen,memtikan,mimal,menyiapkan,pembayaran,tenant,semua
# cluster 4
# manager,driver,supervis,presecost,merrcost,accountgbachel,wker,licenseswillg,cost,presemarketg,month,tentmale,traee,it,banquet,front,food,communicion,same,favh,favfresh,staffbachel,mics,technicianh,applyit,segmentfemaleexperience,goverment,systemprefer,manyarsales,teamfront,havg,departmenth,merrfront,teamexecutive,housekeepgmaleexperience,merr,control,power,teamroom,merrhousekeepg,consideredh,presesales,staff,me,merrit,is,verages,leadership,merrst,degree,pro,departmenthavg,programwill,skillgood,merrsales,leader,keeper,abilityh,lookgexperience,teamsales,agent,tent,sales,psione,chief,yearprefer,system,accountg,loyalh,st,titude,comg,yearh,experiences,desk,loyalwillg,abaya,are,titudepsione,under,titudewillg,mimum,rounng,domicile,dustry,vhp,year,hospitality,executive,team,housekeepg,wk,player,good,key,dynamic,experience,gunawangsa,personality,hotel
# cluster 5
# suu,setiap,mengikuti,somipengalaman,tempkan,rtanggung,tugkan,seg,menangani,faks,clerical,terb,tetapi,focopy,rsig,ce,menyusun,perusahaanmampu,pembangunan,pertanahan,pera,hadapi,kemampuan,bawah,analisa,proyek,big,mensuppt,melaksanakan,pkpa,acara,memahami,mereview,penkan,sukai,project,sipl,terhadap,bisnis,lulusan,racara,penipuan,sengketa,bank,sukaiusia,tekananlegal,maksimal,bhs,persyaran,vidusiap,monirg,pembuan,teg,li,mengelolah,mana,dalam,tim,staffpenkan,presi,under,jual,perikan,advok,th,baik,menarikpenempan,presepenampilan,persigan,mimal,mpun,menguai,sejenisnyiap,peruran,pia,khususnya,review,umum,kus,opion,pengalaman,sejenisnyalegal,sertifik,abayalegal,khusus,kerja,mampu,rhubungan,contract,dokumen,ung,perusahaan,konsep,perda,keksi,kontrak,kerjama,perjanjian,legal,hukum
# cluster 6
# claim,tention,files,accommodion,matag,typg,bookg,pussekretaris,transpt,details,secretarian,ganizg,conferences,prive,compilg,schedulg,crespondence,mutes,mters,arrangg,rept,event,admistrion,confidential,repts,daily,skills,phone,prepare,response,central,project,travel,market,product,by,possess,bisnis,specialized,department,perm,which,meetg,executive,duties,develop,ke,strong,manage,any,al,lookg,gpa,appearance,human,needs,excellence,such,equivalent,permg,development,company,mimum,cide,posses,tractive,fluent,both,old,age,management,sciple,self,busess,required,on,placed,english,willg,ft,skill,written,marketg,good,bachel,cusmer,provide,terpersonal,must,or,degree,new,jakarta,reled,let,communicion,experience,sales,wk,field
# cluster 7
# rkoni,merial,isiif,memtikan,meng,memrsihkan,melamar,mea,pajak,komunikif,programmer,bantu,tim,terhadap,teliti,gaji,ku,video,area,konstruksi,jurusan,dap,menja,la,konsep,segala,proses,hal,system,ga,affair,komputer,fice,ke,dari,gambar,perempuan,pembayaran,kebutuhan,posisi,hil,it,fresh,rk,mengenai,negosii,rab,jujur,gradue,al,apliki,dokumen,ms,ide,kreif,mampu,transaksi,team,microst,barang,semua,sistem,baru,perhitungan,setidaknya,akuntansi,max,pekerjaan,pengetahuan,accountg,menguai,sama,sebagai,terkait,rtanggung,baik,komuniki,bawah,desa,design,analisa,teknik,karyawan,usia,perusahaan,bisa,big,laki,keuangan,admistri,penkan,maksimal,sesuai,da,lapan,pengalaman,kemampuan,dalam,mimal,kerja

# %%
kmeans.predict(user_tfidf[0, :])
# Out:
# array([7])

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import surprise
from surprise import SVD
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise import Reader, Dataset
from surprise import KNNBasic

# %%
df_applicant['ApplicantID'] = df_applicant.index

# %%
df_pipeline = pd.read_csv('data/cdf_pipeline.csv')
df_stage = pd.read_csv('data/cdf_stage.csv')

df_stage = pd.merge(df_pipeline, df_stage, on=['StageID'])

# %%
df_stage = df_stage[['ApplicantID', 'StageID']]

# %%
df_applicant.index.names = ['Index']

# %%
df_applicant = pd.merge(df_applicant, df_stage, on=['ApplicantID'])

# %%
df_applicant = df_applicant[['History', 'ApplicantID', 'StageID']]

# %%
reader = Reader()
data = Dataset.load_from_df(df_applicant, reader)

# Train & Test
trainset, testset = train_test_split(data, test_size=0.20, random_state=50)

# %%
algo_svd = SVD()
prediction_mf = algo_svd.fit(trainset).test(testset)

# %%
recom_svd = algo_svd.predict(uid='data warehouse', iid='AWMjT0WguC1rwyj_rFh3')
recom_svd
# Out:
# Prediction(uid='data warehouse', iid='AWMjT0WguC1rwyj_rFh3', r_ui=None, est=5, details={'was_impossible': False})

# %%
df_applicant.head(2)
# Out:
#            Strengthness Weaknesses   Industry JobDescription   Position
# Applica...
# 1                                   jasa k...  pembua...      staff ...
# 3           pekerj...    pelupa...  teleko...  mainte...      sales ...

# %%
tes = df_job.JobTitle

# %%
for i in tes:
    print(i)
# Out:
# night audit
# internal audit staff
# staff
# internal audit
# test
# manager marketing
# staff hrd
# tenant relation
# admin support business development
# leasing apartemen
# marketing staff
# admin support research development
# leasing apartment
# test data hilang
# test job
# finance accounting
# finance accounting
# book keeper
# book keeper accounting department
# it android programmer
# it support
# it android programmer
# admin it
# it android programmer
# it android programmer
# network dan it security specialist
# android programmer
# android programmer
# sekretaris legal
# sekretaris legal
# sekretaris legal pajak ijin
# sekretaris direksi
# executive secretary
# senior sekretaris
# sekretaris direksi
# sekretaris
# sekretaris lokasi
# sekretaris lokasi
# senior sekretaris
# sekretaris direksi
# sekretaris lokasi
# sekretaris
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris direksi
# sekretaris direksi
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris direksi
# sekretaris direksi
# sekretaris direksi
# sekretaris direksi
# marketing executive
# account executive marketing
# senior marketing
# marketing communication for mall
# marketing executive
# marketing
# marketing bali
# marketing staff
# account executive marketing
# marketing communication
# marketing executive
# marketing communication
# manager business development
# manager marketing
# marketing property staff
# marketing karaoke entertainment centre
# marketing bali
# marketing surabaya
# marketing surabaya
# marketing software
# marketing bali
# marketing executive
# senior marketing property
# marketing executive
# marketing ci
# marketing bali
# account executive
# marketing executive
# marketing executive
# account executive
# marketing bali
# marketing manager
# marketing manager
# marketing property
# marketing supervisor
# marketing leasing
# marketing apps
# marketing property
# marketing leasing
# staff marketing
# marketing freelance
# account executive
# account executive
# administrasi
# admin gudang
# staff traffic
# manager operational
# karaoke and entertainment centre manager
# general manager hotel
# manager operational
# general manager hotel
# asst food beverage
# accounting staff
# kasir
# accounting staff
# general cashier
# accounting staff
# cashier accounting
# cashier accounting staff
# chasier
# staff finance accounting
# kasir
# penjaga stand
# capt
# capt
# waitress fb cashier
# banquet attendant
# staff outlet
# waitress
# waitress
# staff accounting
# general cashier
# it staff
# it staff
# technical support
# it support
# it support
# it staff
# it support
# it support
# it support
# staff it
# it support
# sales marketing manager
# marketing manager
# marketing manager
# admin support business development
# admin support business development
# franchise business development manager
# staff
# staff research development
# admin support business development
# staff research development
# asst manager leasing mall
# business development senior spv
# social media officer
# cost control accounting department
# admin teknik
# cost control
# sekretaris direksi
# sekretaris direksi
# sekretaris
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris
# sekretaris
# sekretaris legal
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris direksi
# sekretaris
# sekretaris
# sekretaris
# sekretaris accounting
# fitout
# staff arsitek
# arsitek
# fitout mall
# fitout ga mall
# interior design
# interior design
# supervisor floor karaoke
# store supervisor resto
# store supervisor resto
# cleaning service puri
# cleaning service
# cleaning service
# cleaning service
# celeaning service
# cleaning service
# cleaning service
# driver
# service advidor teknisi
# cleaning service
# tenant relation
# resident relation
# resident relation
# tenant relation
# tenant relation
# tenant relation
# front desk agent
# front desk agent dw
# front desk agent
# front desk agent fda
# front desk agent
# front desk agent fda
# front desk agent fda
# cook
# chef de partie cdp
# kitchen staff gunawangsa hotel merr
# cook
# staff outlet boba
# staff outlet
# staff outlet
# staff outlet
# staff outlet
# staff outlet
# cleaning service
# staff outlet
# manager outlet
# public area attendant
# koordinator maintenance
# tukang listrik
# supervisor lapangan
# staff umum makassar
# ptk maintenance las cover
# maintenance las
# tukang listrik
# admin general operational
# qc lapangan
# building manager
# graphic design marketing communication
# staff desain
# graphic design staff
# senior staff hrd
# supervisor hrga
# marketing it
# marketing software
# social media manager
# marketing software
# marketing software
# marketing software
# marketing software
# marketing software
# marketing software
# marketing software
# housekeeping supervisor
# housekeeping ordertaker
# housekeeping room attendant
# estimator
# pengawas lapangan
# surveyor lapangan
# chief accounting

# %%
df_job.JobTitle.value_counts()
# Out:
# legal staff              35
# driver                   27
# engineering staff        26
# sekretaris               18
# sekretaris direksi       17
#                          ..
# sous chef                 1
# kitchen                   1
# internal audit staff      1
# waiter waitress resto     1
# surveyor lapangan         1
# Name: JobTitle, Length: 372, dtype: int64

# %%
tfidf = TfidfVectorizer()
matrix = tfidf.fit_transform(tes.drop_duplicates().values)

pairwise_similarity = matrix * matrix.T

arr = pairwise_similarity.toarray()
np.fill_diagonal(arr, 0)

input_doc = 'estimator'

input_idx = list(tes.values).index(input_doc)

result_idx = np.nanargmax(arr[input_idx])

list(tes.values)[result_idx]
# Out:
# 'night audit'

# %%
arr
# Out:
# array([[       nan, 0.44131453, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.44131453,        nan, 0.2546966 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.2546966 ,        nan, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ...,        nan, 0.50447859,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.50447859,        nan,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#                nan]])

# %%
# Out:
# Empty DataFrame
# Columns: [Description, JobTitle, Requirement, FunctionPositionName]
# Index: []
